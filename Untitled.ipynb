# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
df = pd.read_csv('overdose_deaths.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69738 entries, 0 to 69737
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          69738 non-null  object
#  1   Year                           69738 non-null  int64
#  2   Month                          69738 non-null  object
#  3   Period                         69738 non-null  object
#  4   Indicator                      69738 non-null  object
#  5   Data Value                     58815 non-null  object
#  6   Percent Complete               69738 non-null  float64
#  7   Percent Pending Investigation  69738 non-null  float64
#  8   State Name                     69738 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 4.8+ MB

# %%
print("Dataset Overview:")
print(df.info())
print("\nFirst 5 rows:")
# Out:
# Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69738 entries, 0 to 69737
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          69738 non-null  object
#  1   Year                           69738 non-null  int64
#  2   Month                          69738 non-null  object
#  3   Period                         69738 non-null  object
#  4   Indicator                      69738 non-null  object
#  5   Data Value                     58815 non-null  object
#  6   Percent Complete               69738 non-null  float64
#  7   Percent Pending Investigation  69738 non-null  float64
#  8   State Name                     69738 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 4.8+ MB
# None
#
# First 5 rows:

# %%
yearly_deaths = df.groupby('Year')['Data Value'].sum().reset_index()
print("\nTotal deaths by year:")
print(yearly_deaths)
# Out:
# Total deaths by year:
#    Year                                         Data Value
# 0  2015  88.09523814,13312687.903225811244,2224,19389.2...
# 1  2016  40114,2621893.93939394609535132116875138121972...
# 2  2017  3011735524497.43589744784,3251643124446484,234...
# 3  2018  5515368014210298.59154934,34038116148110734,38...
# 4  2019  4478100554519104,40558351196512504043784220130...
# 5  2020  1094.16666667303412056363157744,5103846531094....
# 6  2021  4917896.62921348117191194841345,18250587118601...
# 7  2022  99.610894946,216162194682571787359154153186491...
# 8  2023  275150203615,5453124501792091698.9090909131202...
# 9  2024  3253999.487179493905,5012223143261327103932236...
