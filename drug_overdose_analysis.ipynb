# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('drug_overdose.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69738 entries, 0 to 69737
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          69738 non-null  object
#  1   Year                           69738 non-null  int64
#  2   Month                          69738 non-null  object
#  3   Period                         69738 non-null  object
#  4   Indicator                      69738 non-null  object
#  5   Data Value                     58815 non-null  object
#  6   Percent Complete               69738 non-null  float64
#  7   Percent Pending Investigation  69738 non-null  float64
#  8   State Name                     69738 non-null  object
#  9   Footnote                       69738 non-null  object
#  10  Footnote Symbol                69738 non-null  object
#  11  Predicted Value                46692 non-null  object
# ...

# %%
df = df.drop(columns=['Percent Pending Investigation', 'Period', 'State Name', 'Footnote', 'Percent Complete', 'Footnote Symbol', 'Predicted Value'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69738 entries, 0 to 69737
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   State       69738 non-null  object
#  1   Year        69738 non-null  int64
#  2   Month       69738 non-null  object
#  3   Indicator   69738 non-null  object
#  4   Data Value  58815 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 2.7+ MB

# %%
overdoses_df = df[(df['State'] == 'US') & 
                 (df['Month'] == 'December') & 
                 (df['Indicator'] == 'Number of Drug Overdose Deaths')]

print(overdoses_df)
# Out:
#       State  Year     Month                       Indicator Data Value
# 57029    US  2015  December  Number of Drug Overdose Deaths     52,623
# 57172    US  2016  December  Number of Drug Overdose Deaths     63,938
# 57308    US  2017  December  Number of Drug Overdose Deaths     70,699
# 57457    US  2018  December  Number of Drug Overdose Deaths     67,850
# 57595    US  2019  December  Number of Drug Overdose Deaths     71,130
# 57738    US  2020  December  Number of Drug Overdose Deaths     92,478
# 57887    US  2021  December  Number of Drug Overdose Deaths    107,573
# 58036    US  2022  December  Number of Drug Overdose Deaths    109,413
# 58170    US  2023  December  Number of Drug Overdose Deaths    106,881

# %%
cocaine = df[df['Indicator'].str.lower().str.contains('Cocaine')]
print(cocaine)
# Out:
# Empty DataFrame
# Columns: [State, Year, Month, Indicator, Data Value]
# Index: []

# %%
indicator = df['Indicator'].unique()
print (indicator)
for indicator in sorted(indicator):
    print(f"- {indicator}")
# Out:
# ['Natural & semi-synthetic opioids (T40.2)' 'Percent with drugs specified'
#  'Number of Deaths' 'Cocaine (T40.5)'
#  'Psychostimulants with abuse potential (T43.6)'
#  'Synthetic opioids, excl. methadone (T40.4)'
#  'Number of Drug Overdose Deaths' 'Heroin (T40.1)'
#  'Opioids (T40.0-T40.4,T40.6)'
#  'Natural, semi-synthetic, & synthetic opioids, incl. methadone (T40.2-T40.4)'
#  'Methadone (T40.3)'
#  'Natural & semi-synthetic opioids, incl. methadone (T40.2, T40.3)']
# - Cocaine (T40.5)
# - Heroin (T40.1)
# - Methadone (T40.3)
# - Natural & semi-synthetic opioids (T40.2)
# - Natural & semi-synthetic opioids, incl. methadone (T40.2, T40.3)
# - Natural, semi-synthetic, & synthetic opioids, incl. methadone (T40.2-T40.4)
# - Number of Deaths
# - Number of Drug Overdose Deaths
# - Opioids (T40.0-T40.4,T40.6)
# - Percent with drugs specified
# - Psychostimulants with abuse potential (T43.6)
# - Synthetic opioids, excl. methadone (T40.4)

# %%
cocaine = df[(df['State'] == 'US') & 
                 (df['Month'] == 'December') & 
                 (df['Indicator'] == 'Cocaine (T40.5)')]

print(cocaine)
# Out:
#       State  Year     Month        Indicator Data Value
# 57018    US  2015  December  Cocaine (T40.5)      6,841
# 57163    US  2016  December  Cocaine (T40.5)     10,458
# 57309    US  2017  December  Cocaine (T40.5)     14,069
# 57456    US  2018  December  Cocaine (T40.5)     14,802
# 57594    US  2019  December  Cocaine (T40.5)     16,024
# 57741    US  2020  December  Cocaine (T40.5)     19,601
# 57882    US  2021  December  Cocaine (T40.5)     24,710
# 58030    US  2022  December  Cocaine (T40.5)     27,921
# 58180    US  2023  December  Cocaine (T40.5)     29,911

# %%
heroin = df[(df['State'] == 'US') & 
                 (df['Month'] == 'December') & 
                 (df['Indicator'] == 'Heroin (T40.1)')]

print(heroin)
# Out:
#       State  Year     Month       Indicator Data Value
# 57023    US  2015  December  Heroin (T40.1)     13,051
# 57173    US  2016  December  Heroin (T40.1)     15,551
# 57306    US  2017  December  Heroin (T40.1)     15,593
# 57461    US  2018  December  Heroin (T40.1)     15,102
# 57600    US  2019  December  Heroin (T40.1)     14,116
# 57742    US  2020  December  Heroin (T40.1)     13,253
# 57883    US  2021  December  Heroin (T40.1)      9,263
# 58032    US  2022  December  Heroin (T40.1)      5,958
# 58176    US  2023  December  Heroin (T40.1)      4,062

# %%
methadone = df[(df['State'] == 'US') & 
                 (df['Month'] == 'December') & 
                 (df['Indicator'] == 'Methadone (T40.3)')]

print(methadone)
# Out:
#       State  Year     Month          Indicator Data Value
# 57020    US  2015  December  Methadone (T40.3)      3,309
# 57164    US  2016  December  Methadone (T40.3)      3,390
# 57314    US  2017  December  Methadone (T40.3)      3,210
# 57453    US  2018  December  Methadone (T40.3)      3,047
# 57597    US  2019  December  Methadone (T40.3)      2,756
# 57747    US  2020  December  Methadone (T40.3)      3,561
# 57892    US  2021  December  Methadone (T40.3)      3,697
# 58029    US  2022  December  Methadone (T40.3)      3,366
# 58178    US  2023  December  Methadone (T40.3)      3,390

# %%
methadone = df[(df['State'] == 'US') & 
                 (df['Month'] == 'December') & 
                 (df['Indicator'] == 'Opioids (T40.0-T40.4,T40.6)')]

print(methadone)
# Out:
#       State  Year     Month                    Indicator Data Value
# 57021    US  2015  December  Opioids (T40.0-T40.4,T40.6)     33,203
# 57170    US  2016  December  Opioids (T40.0-T40.4,T40.6)     42,435
# 57316    US  2017  December  Opioids (T40.0-T40.4,T40.6)     47,885
# 57454    US  2018  December  Opioids (T40.0-T40.4,T40.6)     47,096
# 57604    US  2019  December  Opioids (T40.0-T40.4,T40.6)     50,178
# 57746    US  2020  December  Opioids (T40.0-T40.4,T40.6)     69,061
# 57884    US  2021  December  Opioids (T40.0-T40.4,T40.6)     80,997
# 58031    US  2022  December  Opioids (T40.0-T40.4,T40.6)     82,851
# 58177    US  2023  December  Opioids (T40.0-T40.4,T40.6)     80,719
